# %% [markdown]
# ### Alpha Vantage Company Overview Data Request
#
# https://www.alphavantage.co/

# %% [markdown]
# Read in 2019-2020 IPO Listing CSV from raw dataset folder

# %%
# Import dependancies
import pandas as pd
import requests
import json
import sys
import time

# Import the API key.
from config2 import stocks_p_api_key

# %%
IPO_df = pd.read_csv('raw_dataset/IPO_Listing_2019_2020.csv')
IPO_df.head()
# Out:
#      IPO_DATE SYMBOL                             NAME  IPO_PRICE  CURRENT  \
# 0  2020-12-29    MRM               Medirom Healthcare       15.0    10.30
# 1  2020-12-24   VTAQ          Ventoux CCM Acquisition       10.0     9.89
# 2  2020-12-23    IKT          Inhibikase Therapeutics       10.0     6.21
# 3  2020-12-23    GBS                        GBS, Inc.       17.0     6.81
# 4  2020-12-23   HCAR  Healthcare Services Acquisition       10.0     9.85
#
#    RETURN
# 0 -0.3133
# 1 -0.0110
# 2 -0.3790
# 3 -0.5994
# 4 -0.0155

# %%
IPO_df.shape
# Out:
# (710, 6)

# %%
IPO_df.dtypes
# Out:
# IPO_DATE      object
# SYMBOL        object
# NAME          object
# IPO_PRICE    float64
# CURRENT      float64
# RETURN       float64
# dtype: object

# %% [markdown]
# Transform IPO_DATE from object to datetime format

# %%
IPO_df['IPO_DATE'] = pd.to_datetime(IPO_df['IPO_DATE'], format = '%Y-%m-%d')

# %%
IPO_df.dtypes
# Out:
# IPO_DATE     datetime64[ns]
# SYMBOL               object
# NAME                 object
# IPO_PRICE           float64
# CURRENT             float64
# RETURN              float64
# dtype: object

# %%
IPO_df.head()
# Out:
#     IPO_DATE SYMBOL                             NAME  IPO_PRICE  CURRENT  \
# 0 2020-12-29    MRM               Medirom Healthcare       15.0    10.30
# 1 2020-12-24   VTAQ          Ventoux CCM Acquisition       10.0     9.89
# 2 2020-12-23    IKT          Inhibikase Therapeutics       10.0     6.21
# 3 2020-12-23    GBS                        GBS, Inc.       17.0     6.81
# 4 2020-12-23   HCAR  Healthcare Services Acquisition       10.0     9.85
#
#    RETURN
# 0 -0.3133
# 1 -0.0110
# 2 -0.3790
# 3 -0.5994
# 4 -0.0155

# %%
# Create a list of IPO symbols from the IPO_df
IPO_list = IPO_df['SYMBOL'].tolist()
IPO_list
# Out:
# ['MRM',
#  'VTAQ',
#  'IKT',
#  'GBS',
#  'HCAR',
#  'CFIV',
#  'VII',
#  'VHAQ',
#  'ACKIT',
#  'SVOK',
#  'GFX',
#  'MASS',
#  'DUNE',
#  'MTAC',
#  'IIII',
#  'MDWT',
#  'SCOA',
#  'COOL',
#  'VIRI',
#  'WISH',
#  'UPST',
#  'CCV',
#  'SCPS',
#  'BCAB',
#  'WNW',
#  'KINZ',
#  'MRAC',
#  'OCG',
#  'BLUW',
#  'ATA',
#  'ABCL',
#  'NBTX',
#  'FDMT',
#  'DWIN',
#  'ROCC',
#  'GLAQ',
#  'MOTV',
#  'EDTX',
#  'SNRH',
#  'GHVI',
#  'TVAC',
#  'CBAH',
#  'VVOS',
#  'CERT',
#  'RMGB',
#  'HYFM',
#  'ABNB',
#  'CTAQ',
#  'PCPC',
#  'NEBC',
#  'DASH',
#  'HMCO',
#  'PUBM',
#  'ALTU',
#  'AI',
#  'FLAC',
#  'CND',
#  'DDMX',
#  'MUDS',
#  'RAAC',
#  'YQ',
#  'SBTX',
#  'SEER',
#  'SGTX',
#  'FTCV',
#  'PTIC',
#  'FPAC',
#  'HTPA',
#  'KNTE',
#  'LOKB',
#  'DCBO',
#  'SPFR',
#  'RSVA',
#  'TACA',
#  'CAP',
#  'SGAM',
#  'FRX',
#  'SPRQ',
#  'HFEN',
#  'OZON',
#  'SV',
#  'VMAR',
#  'GNPK',
#  'VCVC',
#  'TINV',
#  'BREZ',
#  'LSAQ',
#  'ARBG',
#  'MRVI',
#  'CAS',
#  'SHC',
#  'KWAC',
#  'OCA',
#  'IIAC',
#  'NGMS',
#  'LNFA',
#  'RTPZ',
#  'TLS',
#  'YSG',
#  'OLMA',
#  'JYAC',
#  'CHFW',
#  'PHIC',
#  'DGNS',
#  'PIPP',
#  'OTRA',
#  'ZNTE',
#  'HAAC',
#  'CFAC',
#  'BWAC',
#  'DMYI',
#  'STIC',
#  'NOAC',
#  'TSIA',
#  'ADOC',
#  'DBDR',
#  'NBA',
#  'LU',
#  'CONX',
#  'SQZ',
#  'JUPW',
#  'BHSE',
#  'AVIR',
#  'ALGM',
#  'LESL',
#  'GLTO',
#  'DSAC',
#  'ROOT',
#  'GATO',
#  'BOAC',
#  'ACIC',
#  'AJAX',
#  'BDSX',
#  'ABST',
#  'MAX',
#  'MACU',
#  'LUXA',
#  'ATAC',
#  'FHTX',
#  'EUCR',
#  'ACAC',
#  'MCFE',
#  'TEKK',
#  'ABCM',
#  'GHLD',
#  'YSAC',
#  'RICE',
#  'CTAC',
#  'BLSA',
#  'HIGA',
#  'SRSA',
#  'MSP',
#  'SPNV',
#  'XPOA',
#  'YGMZ',
#  'LFTR',
#  'DCRB',
#  'GWAC',
#  'HLXA',
#  'HZON',
#  'BTWN',
#  'EAR',
#  'TARS',
#  'KRBP',
#  'OPT',
#  'PRAX',
#  'TMPM',
#  'ALGS',
#  'TMTS',
#  'EBC',
#  'ARRY',
#  'MNSO',
#  'MOTN',
#  'FVAM',
#  'CDAK',
#  'IPOD',
#  'IPOE',
#  'IPOF',
#  'INTZ',
#  'SPRB',
#  'STTK',
#  'KRON',
#  'LCY',
#  'IH',
#  'PAIC',
#  'FUBO',
#  'AZYO',
#  'NGAC',
#  'MAAC',
#  'EMPW',
#  'SQFT',
#  'PACE',
#  'TPGY',
#  'FMAC',
#  'APSG',
#  'IMNM',
#  'AVAN',
#  'ASAQ',
#  'IACA',
#  'SEAH',
#  'ASO',
#  'ONCR',
#  'CCCC',
#  'VGAC',
#  'VYGG',
#  'IMPX',
#  'LXEH',
#  'THRY',
#  'AGC',
#  'AVO',
#  'IGAC',
#  'LUNG',
#  'RCHG',
#  'BQ',
#  'VSPR',
#  'PLTR',
#  'QELL',
#  'CD',
#  'ASAN',
#  'YALA',
#  'CLII',
#  'FGNA',
#  'ORPH',
#  'AMST',
#  'FTIV',
#  'VACQ',
#  'SYTA',
#  'PRLD',
#  'GLSI',
#  'PMVP',
#  'GRAY',
#  'VIAO',
#  'TSHA',
#  'PDAC',
#  'ACTC',
#  'CRSR',
#  'VIH',
#  'GDRX',
#  'LSF',
#  'ASPL',
#  'BSY',
#  'FCAC',
#  'PMVC',
#  'CMPS',
#  'AHAC',
#  'U',
#  'VTRU',
#  'ATHA',
#  'NMMC',
#  'STWO',
#  'DYN',
#  'AMWL',
#  'SUMO',
#  'OACB',
#  'PTVE',
#  'RTP',
#  'BNL',
#  'EQD',
#  'STEP',
#  'SNOW',
#  'ENPC',
#  'MTCR',
#  'FROG',
#  'SBG',
#  'OM',
#  'SAII',
#  'SNPR',
#  'TWCT',
#  'LEAP',
#  'LSPD',
#  'BSN',
#  'SVAC',
#  'PIAI',
#  'NSH',
#  'CRHC',
#  'ITAC',
#  'TWND',
#  'CAPA',
#  'INAQ',
#  'BCTG',
#  'CMLF',
#  'PRFX',
#  'AUVI',
#  'HCDI',
#  'GP',
#  'XPEV',
#  'BTAQ',
#  'CFII',
#  'FTOC',
#  'CLA',
#  'FST',
#  'KYMR',
#  'HZAC',
#  'NNOX',
#  'HRMY',
#  'INBX',
#  'BFT',
#  'STPK',
#  'FIII',
#  'AONE',
#  'NGA',
#  'LCAP',
#  'CVAC',
#  'DGNR',
#  'DMYD',
#  'DCT',
#  'NTST',
#  'BEKE',
#  'RBAC',
#  'FAII',
#  'KBNT',
#  'FSDC',
#  'VMAC',
#  'ARYA',
#  'CMPI',
#  'FRLN',
#  'IBEX',
#  'KSMT',
#  'GRSV',
#  'AFIB',
#  'RKT',
#  'OSH',
#  'RXT',
#  'BOWX',
#  'BIGC',
#  'HOL',
#  'GOAC',
#  'YAC',
#  'HSAQ',
#  'VITL',
#  'FTHM',
#  'ETAC',
#  'NHIC',
#  'VSTA',
#  'PRPB',
#  'GOED',
#  'CCIV',
#  'LI',
#  'ALVR',
#  'VERX',
#  'ACEV',
#  'ITOS',
#  'INZY',
#  'ACND',
#  'ANNX',
#  'GRCY',
#  'NRIX',
#  'EDTK',
#  'ERES',
#  'MEG',
#  'PSAC',
#  'PSTH',
#  'JAMF',
#  'ALXO',
#  'RNLX',
#  'DFHT',
#  'BLI',
#  'PAND',
#  'TIG',
#  'RLAY',
#  'GOCO',
#  'MLAC',
#  'DEH',
#  'HPX',
#  'AACQ',
#  'NCNO',
#  'PTK',
#  'PSTX',
#  'NKTX',
#  'QH',
#  'IVA',
#  'BLCT',
#  'TXAC',
#  'RACA',
#  'LMND',
#  'CPSR',
#  'ACCD',
#  'PANA',
#  'DNB',
#  'GSAH',
#  'ADTX',
#  'API',
#  'ACI',
#  'FUSE',
#  'KCAC',
#  'PYPD',
#  'EBON',
#  'FUSN',
#  'AKUS',
#  'BRLI',
#  'GTH',
#  'NUZE',
#  'RPTX',
#  'PROG',
#  'FMTX',
#  'TREB',
#  'RPRX',
#  'BNR',
#  'AZEK',
#  'PCVX',
#  'RNA',
#  'GBIO',
#  'LTRN',
#  'UCL',
#  'HEC',
#  'VRM',
#  'LEGN',
#  'MCAC',
#  'AMTI',
#  'CALT',
#  'FOUR',
#  'ARYB',
#  'DADA',
#  'ZI',
#  'WMG',
#  'PLRX',
#  'WPF',
#  'NARI',
#  'LGVW',
#  'SLQT',
#  'BMRG',
#  'NOVS',
#  'ADCT',
#  'GIK',
#  'JWS',
#  'CLEU',
#  'KC',
#  'AYLA',
#  'LOAK',
#  'SOAC',
#  'GAN',
#  'ROCH',
#  'CGRO',
#  'LYRA',
#  'FVAC',
#  'IPOB',
#  'ORIC',
#  'PCPL',
#  'CHAQ',
#  'IPOC',
#  'KROS',
#  'ZNTL',
#  'WIMI',
#  'IMRA',
#  'DFPH',
#  'LSAC',
#  'FEAC',
#  'GFL',
#  'PASG',
#  'ZCMD',
#  'DMYT',
#  'ESSC',
#  'CCXX',
#  'NBAC',
#  'MEDS',
#  'ZGYH',
#  'RVMD',
#  'GRIL',
#  'HUIZ',
#  'CCAC',
#  'GNRS',
#  'PFHD',
#  'ONEW',
#  'NREF',
#  'SDGR',
#  'BEAM',
#  'CSPR',
#  'PPD',
#  'ONEM',
#  'REYN',
#  'ARQT',
#  'ANPC',
#  'BDTX',
#  'ANVS',
#  'SCVX',
#  'GHIV',
#  'VEL',
#  'IMAB',
#  'LIZI',
#  'DNK',
#  'MKD',
#  'MNPR',
#  'INDO',
#  'CIIC',
#  'HCCO',
#  'SPT',
#  'OCFT',
#  'BILL',
#  'EH',
#  'XP',
#  'LIVK',
#  'LMPX',
#  'ALUS',
#  'CHPM',
#  'PINE',
#  'PTAC',
#  'SITM',
#  'CAN',
#  'SAQN',
#  'AMHC',
#  'GRNV',
#  'YAYO',
#  'ETNB',
#  'SRAC',
#  'KRKR',
#  'JIH',
#  'TELA',
#  'CNSP',
#  'MOHO',
#  'CNTG',
#  'DFNS',
#  'GRTX',
#  'SI',
#  'MCMJ',
#  'QK',
#  'DUO',
#  'FSRV',
#  'SFTW',
#  'RAPT',
#  'OYST',
#  'PHAT',
#  'PGNY',
#  'TFFP',
#  'DAO',
#  'AIH',
#  'CABA',
#  'HAPP',
#  'BRP',
#  'GLEO',
#  'LATN',
#  'IPHA',
#  'BRBR',
#  'VIR',
#  'HBT',
#  'BNTX',
#  'VIE',
#  'MCBS',
#  'FREQ',
#  'APRE',
#  'PTON',
#  'OPRT',
#  'PING',
#  'DDOG',
#  'XGN',
#  'IGMS',
#  'NVST',
#  'APXT',
#  'SWTX',
#  'NET',
#  'STSA',
#  'EXPC',
#  'ALRS',
#  'TXG',
#  'SDC',
#  'NPA',
#  'JFU',
#  'CFB',
#  'PLIN',
#  'THBR',
#  'SSPK',
#  'INMD',
#  'HKIB',
#  'ORSN',
#  'KRUS',
#  'SNDL',
#  'DT',
#  'NFIN',
#  'BORR',
#  'VIST',
#  'CCX',
#  'BHAT',
#  'SBE',
#  'WSG',
#  'HCAT',
#  'NOVA',
#  'LVGO',
#  'CSTL',
#  'PROS',
#  'EIC',
#  'MDLA',
#  'IFS',
#  'AFYA',
#  'PHR',
#  'MIRM',
#  'CPAA',
#  'ORCC',
#  'AMK',
#  'OAC',
#  'FULC',
#  'IHRT',
#  'DOYU',
#  'SCPE',
#  'PIC',
#  'THCA',
#  'RMBI',
#  'KRTX',
#  'REAL',
#  'MORF',
#  'ADPT',
#  'CHNG',
#  'BBIO',
#  'LINX',
#  'CMBM',
#  'AKRO',
#  'PSNL',
#  'GO',
#  'BCEL',
#  'WORK',
#  'PRVL',
#  'SMMC',
#  'STOK',
#  'CHWY',
#  'FVRR',
#  'MWK',
#  'CRWD',
#  'RVLV',
#  'HYAC',
#  'GIX',
#  'GSX',
#  'BCYC',
#  'RTLR',
#  'IDYA',
#  'GXGX',
#  'FSLY',
#  'AVTR',
#  'LKNCY',
#  'PSTL',
#  'APLT',
#  'AGBA',
#  'SONM',
#  'UBER',
#  'JFIN',
#  'MEC',
#  'CRTX',
#  'SPFI',
#  'NXTC',
#  'AXLA',
#  'HHR',
#  'PSN',
#  'LCA',
#  'TRVI',
#  'TBBA',
#  'SCPL',
#  'YJ',
#  'RRBI',
#  'ATIF',
#  'BYND',
#  'SY',
#  'TMDX',
#  'WAFU',
#  'HOOK',
#  'PINS',
#  'ZM',
#  'GNLN',
#  'MNRL',
#  'PLMR',
#  'TPTX',
#  'BWAY',
#  'JMIA',
#  'TUFN',
#  'PD',
#  'GHSI',
#  'SILK',
#  'RPLA',
#  'NGM',
#  'TW',
#  'RUHN',
#  'PBTS',
#  'LYFT',
#  'PUYI',
#  'DTIL',
#  'JFK',
#  'WTRE',
#  'GNFT',
#  'LEVI',
#  'INSU',
#  'TIGR',
#  'TRNE',
#  'FUTU',
#  'CRSA',
#  'SWAV',
#  'THCB',
#  'HCAC',
#  'KLDO',
#  'SHLL',
#  'DPHC',
#  'SLGG',
#  'ACAM',
#  'SOLY',
#  'AREC',
#  'MITO',
#  'HOTH',
#  'TCRR',
#  'IMAC',
#  'ANCN',
#  'HARP',
#  'RMG',
#  'GOSS',
#  'MNCL',
#  'ALEC',
#  'IPV',
#  'INMB',
#  'GMHI',
#  'NFE',
#  'ANDA',
#  'RBKB',
#  'BCOW',
#  'MDJH',
#  'MTC',
#  'SXTC']

# %%
# Check length of IPO_list
len(IPO_list)
# Out:
# 710

# %% [markdown]
# ### Request Company Overview Data from Alpha Vantage
#
# Create a loop to retreive company overview data for each symbol in the IPO_list

# %%
# Define url

base_company_overview_url = "https://www.alphavantage.co/query?function=OVERVIEW&symbol="


# Create individual lists to house each reponse from API request

SYMBOL_List = []
ASSET_TYPE_List = []
NAME_List = []
EXCHANGE_List = []
CURRENCY_List = []
COUNTRY_List = []
SECTOR_List = []
INDUSTRY_List = []
ADDRESS_List = []

KEY_ERROR_List = []

# Create For loop to fetch responses from Alpha Vantage

for symbol in IPO_list:
    
    symbol_parameter = symbol
    
    full_url = f'{base_company_overview_url}{symbol_parameter}&apikey={stocks_p_api_key}'

    # Make an API call to the API and get the JSON object
    response = requests.get(full_url).json()
    time.sleep(1)
    
    try:
        SYMBOL_response = response['Symbol']
        ASSET_TYPE_response = response['AssetType']
        NAME_response = response['Name']
        EXCHANGE_response = response['Exchange']
        CURRENCY_response = response['Currency']
        COUNTRY_response = response['Country']
        SECTOR_response = response['Sector']
        INDUSTRY_response = response['Industry']
        ADDRESS_response = response['Address']

        SYMBOL_List.append(SYMBOL_response)
        ASSET_TYPE_List.append(ASSET_TYPE_response)
        NAME_List.append(NAME_response)
        EXCHANGE_List.append(EXCHANGE_response)
        CURRENCY_List.append(CURRENCY_response)
        COUNTRY_List.append(COUNTRY_response)
        SECTOR_List.append(SECTOR_response)
        INDUSTRY_List.append(INDUSTRY_response)
        ADDRESS_List.append(ADDRESS_response)
    
    except KeyError:
        print(f"KeyError occured on {symbol}")
        KEY_ERROR_List.append(symbol)
# Out:
# KeyError occured on DWIN
# KeyError occured on HFEN
# KeyError occured on INAQ
# KeyError occured on CFII
# KeyError occured on FSDC
# KeyError occured on TXAC
# KeyError occured on PANA
# KeyError occured on KCAC
# KeyError occured on MCAC
# KeyError occured on LGVW
# KeyError occured on BMRG
# KeyError occured on NOVS
# KeyError occured on LOAK
# KeyError occured on ROCH
# KeyError occured on FVAC
# KeyError occured on IPOB
# KeyError occured on PCPL
# KeyError occured on IPOC
# KeyError occured on LSAC
# KeyError occured on FEAC
# KeyError occured on DMYT
# KeyError occured on CCXX
# KeyError occured on HCCO
# KeyError occured on PTAC
# KeyError occured on SAQN
# KeyError occured on YAYO
# KeyError occured on NFIN
# KeyError occured on CCX
# KeyError occured on SBE
# KeyError occured on CPAA
# KeyError occured on OAC
# KeyError occured on PIC
# KeyError occured on SMMC
# KeyError occured on HYAC
# KeyError occured on LKNCY
# KeyError occured on LCA
# KeyError occured on TBBA
# KeyError occured on JFK
# KeyError occured on INSU
# KeyError occured on TRNE
# KeyError occured on HCAC
# KeyError occured on SHLL
# KeyError occured on DPHC
# KeyError occured on ACAM
# KeyError occured on ANCN
# KeyError occured on RMG
# KeyError occured on MNCL
# KeyError occured on IPV
# KeyError occured on GMHI

# %%
# Check the number of symbols not found on Alpha Vantage
len(KEY_ERROR_List)
# Out:
# 49

# %%
# Transform each list into a series

SYMBOL_Series = pd.Series(SYMBOL_List)
ASSET_TYPE_Series = pd.Series(ASSET_TYPE_List)
NAME_Series = pd.Series(NAME_List)
EXCHANGE_Series = pd.Series(EXCHANGE_List)
CURRENCY_Series = pd.Series(CURRENCY_List)
COUNTRY_Series = pd.Series(COUNTRY_List)
SECTOR_Series = pd.Series(SECTOR_List)
INDUSTRY_Series = pd.Series(INDUSTRY_List)
ADDRESS_Series = pd.Series(ADDRESS_List)

# %%
frame = {
    'SYMBOL': SYMBOL_Series,
    'ASSET_TYPE': ASSET_TYPE_Series,
    'NAME': NAME_Series,
    'EXCHANGE': EXCHANGE_Series,
    'CURRENCY': CURRENCY_Series,
    'COUNTRY': COUNTRY_Series,
    'SECTOR': SECTOR_Series,
    'INDUSTRY': INDUSTRY_Series,
    'ADDRESS': ADDRESS_Series
}

# %%
company_overview_df = pd.DataFrame(frame)
company_overview_df
# Out:
#     SYMBOL    ASSET_TYPE                                         NAME  \
# 0      MRM  Common Stock          MEDIROM Healthcare Technologies Inc
# 1     VTAQ  Common Stock                 Ventoux CCM Acquisition Corp
# 2      IKT  Common Stock                 Inhibikase Therapeutics, Inc
# 3      GBS  Common Stock                                      GBS Inc
# 4     HCAR  Common Stock  Healthcare Services Acquisition Corporation
# ..     ...           ...                                          ...
# 656   RBKB  Common Stock                       Rhinebeck Bancorp, Inc
# 657   BCOW  Common Stock               1895 Bancorp of Wisconsin, Inc
# 658   MDJH  Common Stock                                     MDJM Ltd
# 659    MTC  Common Stock                                   Mmtec, Inc
# 660   SXTC  Common Stock               China SXT Pharmaceuticals, Inc
#
#     EXCHANGE CURRENCY COUNTRY              SECTOR  \
# 0     NASDAQ      USD     USA   Consumer Cyclical
# 1     NASDAQ      USD     USA  Financial Services
# 2     NASDAQ      USD     USA          Healthcare
# 3     NASDAQ      USD     USA          Healthcare
# 4     NASDAQ      USD     USA  Financial Services
# ..       ...      ...     ...                 ...
# 656   NASDAQ      USD     USA  Financial Services
# 657   NASDAQ      USD     USA  Financial Services
# 658   NASDAQ      USD     USA         Real Estate
# 659   NASDAQ      USD     USA          Technology
# 660   NASDAQ      USD     USA          Healthcare
#
#                                    INDUSTRY  \
# 0                         Personal Services
# 1                           Shell Companies
# 2                             Biotechnology
# 3                           Medical Devices
# 4                           Shell Companies
# ..                                      ...
# 656                          Banks-Regional
# 657                          Banks-Regional
# 658                    Real Estate Services
# 659                    Software-Application
# 660  Drug Manufacturers-Specialty & Generic
#
#                                                ADDRESS
# 0              Tradepia Odaiba, Tokyo, Japan, 135-0091
# 1    1 East Putnam Avenue, Greenwich, CT, United St...
# 2    3350 Riverwood Parkway, Atlanta, GA, United St...
# 3    708 3rd Avenue, New York, NY, United States, 1...
# 4    7809 Woodmont Avenue, Bethesda, MD, United Sta...
# ..                                                 ...
# 656  2 Jefferson Plaza, Poughkeepsie, NY, United St...
# 657  7001 West Edgerton Avenue, Greenfield, WI, Uni...
# 658                      Saidun Center, Tianjin, China
# 659  Air China Century Building, Beijing, China, 10...
# 660  No.178 North Taidong Road, Taizhou, China, 225300
#
# [661 rows x 9 columns]

# %%
# Exporting company overview dataframe to csv file
company_overview_df.to_csv('raw_dataset/company_overview.csv')
